# %%
import matplotlib.pyplot as plt

# %%
import math

# %%
class Coronavirus:
    def __init__(self, init_day, E, p):
        self.nd = init_day
        self.e = E
        self.p = p
    


    def ddaytime(self, total_population):
        ls = []
        days = 0
        while(self.nd < total_population):
            ls.append(self.nd)
            self.nd = self.nd*(1+self.e*self.p)
            days += 1
        return ls

# %%
c = Coronavirus(1, 25, 0.6)
y = c.ddaytime(1_000_000_000)
x = [a for a in range(1, len(y)+1)]
print(x, y)
plt.plot(x, y)
plt.xlabel("Days")
plt.ylabel("Population Infected")
plt.show()
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8] [1, 16.0, 256.0, 4096.0, 65536.0, 1048576.0, 16777216.0, 268435456.0]

# %%
y2 = [math.log(a, 10) for a in y]

# %%
print(y2)
# Out:
# [0.0, 1.2041199826559246, 2.408239965311849, 3.6123599479677737, 4.816479930623698, 6.020599913279623, 7.224719895935547, 8.428839878591472]

# %%
plt.plot(x, y2)
plt.xlabel("Days")
plt.ylabel("Population Infected '(in log)'")
# Out:
# Text(0, 0.5, "Population Infected '(in log)'")
